# %% [markdown]
# # Excercise 2

# %% [markdown]
# ## Conversation using <i>if/else/elif</i> statement

# %% [markdown]
# We learned how to use these commands, its main purpose is to stablish some conditions that have to be fulfilled in order to do something

# %%
import time
print("Hello! I'm a computer, and I'm programmed to do somthing interesting, wanna try?")
ans=input()
if ans=="Yes" or ans=="yes":
    print("\nLet's do it!", end=' ')
elif ans=="No" or ans=="no":
    print("\nCome on! Let's do it anyway!", end=' ')
else:
    print("\nOk...", end=' ')
    time.sleep(1)
    print("I dunno what did you wrote, but we'll do it anyway")
num=int(input("Please, write a number between 1 and 10\n"))
if 1<num and num<10:
    print("\nOK, just to confirm, you said \"10\", right?")
else:
    print("\nOK...", end=' ')
    time.sleep(1)
    print("That number is invalid, so I'll say you wrote \"10\", it's that OK?")
ans=input()
if ans=="Yes" or ans=="yes":
    if num==10:
        print("\nPerfect! so let's continue!")
    else:
        print(f"\nPerfect! so let's continue trying to forget you wrote \"{num}\"!")
elif ans=="No" or ans=="no":
    print("\nCome on! I'm a computer, I cannot lie!")
else:
    print("\nOk...", end=' ')
    time.sleep(1)
    print("Does not matter... Just continue...")
time.sleep(1)
par=int(input("Now we need a number between 1 and 3\n"))
if par==1 or par==2:
    print("\nOK, \"3\" sounds perfect to me")
elif par==3:
    print("\nThat's what I thought")
else:
    print("\nOK...", end=' ')
    time.sleep(1)
    if num<1 or num>10:
        print("Again...", end=' ')
    print("Invalid number... Just say that you wrote \"3\"...")
    time.sleep(1)
ans=str(input("Just to know, the first number was 10 and the second one is 3, right?\n"))
if ans=="Yes" or ans=="yes":
    print("\nOK, all seems to be in order!")
elif ans=="No" or ans=="no":
    print("\nWhy are you trying to lie me? I have in my ROM that you wrote those numbers!")
else:
    print("\nOk...", end=' ')
    time.sleep(1)
    print(f"It was a Yes-or-No question, there was no reason to answer \"{ans}\"")
print("\n Well... I will have a 10 out to 10 in the third unit, isn't it? :D")
ans=input()
if ans=="Yes" or ans=="yes":
    print("\n It was a joke, I hope be able to reach it!")
elif ans=="No" or ans=="no":
    print("\nOK, at least I tried it :D anyway, it was a joke")
else:
    print("\nWell...", end=' ')
    time.sleep(1)
    print("I'm not programmed to understand you")
ans=str(input("\nAs I need to say 10 lines in this conversation, do you want an interestig fact?\n"))
if ans=="Yes" or ans=="yes":
    print("\nYou'll get it!")
elif ans=="No" or ans=="no":
    print("\nLet's do it anyway! it is really interesting")
else:
    print("\nI'm sorry...", end=' ')
    time.sleep(1)
    print("I dunno what did you wrote... I'll take it as a positive answer :D")
ans=str(input("\nThink in a 4 digits number... You cannot repeat digits... Do you get it?\n"))
if ans=="Yes" or ans=="yes":
    print("\nPerfect! You're ready for the fun!")
elif ans=="No" or ans=="no":
    print("\nDo it, an then you do the next step")
else:
    print("Just say yes or no, please :(")
print("\nNow you have to put it in an increasing way and subtract the decreasing way...")
time.sleep(1)
print("For example, if you said 7638 it would be: 8763-3678")
time.sleep(10)
print("Now you have to do the operation over and over again, do you get it?")
ans=input()
if ans=="Yes" or ans=="yes":
    print("\nOK, prepare to be surprised!")
elif ans=="No" or ans=="no":
    print("\nDon't be lazy and do it!")
else:
    print("ERROR I'm not programmed to understand you :(")
print("\nAt the end you will get 6174 and that number will be a bucle :D")
ans=int(input("\nSo, how old are you?\n"))
if ans<18:
    print("\nHey! I know that mathematics can be annoying at that age, but it can be interesting as you have seen")
elif ans>18 and ans<60:
    print("\nSuch an interesting fact, isn't it?")
else:
    print("Never is too late to learn something new!")
# Out:
# Hello! I'm a computer, and I'm programmed to do somthing interesting, wanna try?
# Yes
#
# Let's do it! Please, write a number between 1 and 10
# 8
#
# OK, just to confirm, you said "10", right?
# No
#
# Come on! I'm a computer, I cannot lie!
# Now we need a number between 1 and 3
# 3
#
# That's what I thought
# Just to know, the first number was 10 and the second one is 3, right?
# Yes
#
# OK, all seems to be in order!
#
#  Well... I will have a 10 out to 10 in the third unit, isn't it? :D
# I don't think so
#
# Well... I'm not programmed to understand you
#
# As I need to say 10 lines in this conversation, do you want an interestig fact?
# Yeah, Why not?
#
# I'm sorry... I dunno what did you wrote... I'll take it as a positive answer :D
#
# Think in a 4 digits number... You cannot repeat digits... Do you get it?
# No
#
# Do it, an then you do the next step
#
# Now you have to put it in an increasing way and subtract the decreasing way...
# ...
